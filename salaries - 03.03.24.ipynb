# %%
import pandas as pd
df = pd.read_csv('salaries.csv')
print(df.to_string())
# Out:
#        company                  job     degree  salary_more_then_100k
# 0       google      sales executive  bachelors                      0
# 1       google      sales executive    masters                      0
# 2       google     business manager  bachelors                      1
# 3       google     business manager    masters                      1
# 4       google  computer programmer  bachelors                      0
# 5       google  computer programmer    masters                      1
# 6   abc pharma      sales executive    masters                      0
# 7   abc pharma  computer programmer  bachelors                      0
# 8   abc pharma     business manager  bachelors                      0
# 9   abc pharma     business manager    masters                      1
# 10    facebook      sales executive  bachelors                      1
# 11    facebook      sales executive    masters                      1
# ...

# %%
salary = df[df['salary_more_then_100k']==1]
salary.shape
# Out:
# (10, 4)

# %%
salary = df[df['salary_more_then_100k']==0]
salary.shape
# Out:
# (6, 4)

# %%
x = pd.get_dummies(x,dtype=int)

# %%
x = df.drop(columns = ['salary_more_then_100k'])
y = df['salary_more_then_100k']
x1 = pd.get_dummies(x,dtype=int)
print(x1.to_string())
# Out:
#     company_abc pharma  company_facebook  company_google  job_business manager  job_computer programmer  job_sales executive  degree_bachelors  degree_masters
# 0                    0                 0               1                     0                        0                    1                 1               0
# 1                    0                 0               1                     0                        0                    1                 0               1
# 2                    0                 0               1                     1                        0                    0                 1               0
# 3                    0                 0               1                     1                        0                    0                 0               1
# 4                    0                 0               1                     0                        1                    0                 1               0
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x1,y,test_size=0.33)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Out:
#  1
#  0,0,1,0,0,1,1,0
# [0]
# C:\Users\loges\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
model.score(x_train,y_train)
# Out:
# 1.0

# %%
n = int(input())
for i in range(n):
    company_abc_pharma,company_facebook,company_google,job_business_manager,job_computer_programmer,job_sales_executive,degree_bachelors,degree_masters = map(int,input().split(','))
    print(model.predict([[company_abc_pharma,company_facebook,company_google,job_business_manager,job_computer_programmer,job_sales_executive,degree_bachelors,degree_masters]])) #bad prediction

# %%
from sklearn.linear_model import LinearRegression
x_train,x_test,y_train,y_test = train_test_split(x1,y,test_size=0.33)

# %%
model1 = LinearRegression()
model1.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model1.score(x_train,y_train)
# Out:
# 0.81859410430839

# %%
from sklearn.linear_model import LogisticRegression
x_train,x_test,y_train,y_test = train_test_split(x1,y,test_size=0.33)

# %%
model2 = LogisticRegression()
model2.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model2.score(x_train,y_train)
# Out:
# 1.0
